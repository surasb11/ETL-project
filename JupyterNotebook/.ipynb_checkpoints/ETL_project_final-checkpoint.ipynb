# %%
# !conda install psycopg2 -y
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# # EXTRACTION

# %%
#### Create a database called 'ETL_db' in pgAdmin 4. Create SQL schema and tables in pgAdmin 4, 
#### setting State as the PRIMARY KEY in all tables:

#### CREATE TABLE wage_2009(
#### year INT NOT NULL,
#### state VARCHAR PRIMARY KEY,
#### high_wage FLOAT NOT NULL,
#### low_wage FLOAT NOT NULL,
#### high_2018 FLOAT NOT NULL,
#### low_2018 FLOAT NOT NULL
#### );

#### CREATE TABLE wage_2010(
#### year INT NOT NULL,
#### state VARCHAR PRIMARY KEY,
#### high_wage FLOAT NOT NULL,
#### low_wage FLOAT NOT NULL,
#### high_2018 FLOAT NOT NULL,
#### low_2018 FLOAT NOT NULL
#### );

#### CREATE TABLE education(
#### state VARCHAR PRIMARY KEY,
#### education_percent FLOAT NOT NULL
#### );

#### CREATE TABLE peace(
#### state VARCHAR PRIMARY KEY,
#### peace_percent FLOAT NOT NULL
#### );

#### SQL query
#### SELECT * FROM wage_2009;
#### SELECT * FROM wage_2010;
#### SELECT * FROM education;
#### SELECT * FROM peace;

# %%
# Dependencies

# brew install postgresql
# !pip install psycopg2
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# The following commands provide the source path for the csv file and store it in a variable. Then this variable is 
# called into a pandas DataFrame, and the first five rows and all the columns of the dataset are displayed. 

# Our first dataset was retrieved from Kaggle.com. It displays the minimum wage "maximum and minimum" for each state 
# in the United States during the years 1968 and 2017.
MinWage_file = "../Resources/MinimumWage_Data.csv"
MinWage_df = pd.read_csv(MinWage_file, encoding ="latin1")
MinWage_df.head()
# Out:
#    Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
# Our second dataset was retrieved from data.world.com. It displays 4 sociological metrics for all 50 states during 
# different years. 

Metrics_file = "../Resources/Metrics_Data.csv"
Metrics_df = pd.read_csv(Metrics_file)
Metrics_df.head()
# Out:
#            State  Percent Educational Attainment  Percent Peace Index  \
# 0  Massachusetts                            38.2                59.92
# 1       Maryland                            37.3                37.10
# 2       Colorado                            35.9                49.48
# 3    Connecticut                            35.6                56.12
# 4     New Jersey                            34.5                47.38
#
#    Percent Above Poverty Rate  Percent Non-religious
# 0                        88.3                     67
# 1                        89.6                     46
# 2                        87.9                     53
# 3                        89.2                     57
# 4                        88.9                     45

# %% [markdown]
# # TRASNFORMATION

# %% [markdown]
# ### The columns in the minimum wage DataFrame (and dataset) include 1. state, 2. year, 3. high value, or the highest value of the several minimum wage values found for one state during a single year, 4. low value, or the lowest value of the several minimum wage values found for one state during a single year, 5. high 2018 represents the 2018 equivalent in dollars for the high value, 6. low 2018 represents the 2018 equivalent in dollars for the low value.

# %%
# The dataset file contains other columns, but we are only interested in the previously mentioned columns. 
# Therefore, we create a new variable that holds the names for the 
# columns of interest. Then a new DataFrame is created, which contains only the columns stored in the previous variable. 
# A copy of the original DataFrame is made to create the second DataFrame, so that the original is kept intact. 
# The columns of this new DataFrame are renamed to the column names given in the SQL tables

MinWage_cols = ["Year","State", "High.Value", "Low.Value", "High.2018", "Low.2018"]
MinWage_df_transformed = MinWage_df[MinWage_cols].copy()

# Rename the column headers
MinWage_df_transformed = MinWage_df_transformed.rename(columns={"Year":"year",
                                                         "State": "state",
                                                         "High.Value":"high_wage",
                                                         "Low.Value":"low_wage",
                                                         "High.2018":"high_2018",
                                                         "Low.2018":"low_2018"
                                                                   })
# We are selecting the rows where Year = 2009, and grouping by state. We are interested in the
# year 2009 for the education attainment analysis, and we are grouping by state so that we can 
# combine with the other tables by state.

MinWage_2009 = MinWage_df_transformed.loc[MinWage_df_transformed['year'] == 2009]
MinWage_2009 = MinWage_2009.groupby('state').mean()
MinWage_2009
# Out:
#                       year  high_wage  low_wage  high_2018  low_2018
# state
# Alabama               2009       0.00      0.00       0.00      0.00
# Alaska                2009       7.15      7.15       8.35      8.35
# Arizona               2009       7.25      7.25       8.46      8.46
# Arkansas              2009       6.25      6.25       7.29      7.29
# California            2009       8.00      8.00       9.34      9.34
# Colorado              2009       7.28      7.28       8.50      8.50
# Connecticut           2009       8.00      8.00       9.34      9.34
# Delaware              2009       7.15      7.15       8.35      8.35
# District of Columbia  2009       7.55      7.55       8.81      8.81
# Federal (FLSA)        2009       6.55      6.55       7.64      7.64
# Florida               2009       7.21      7.21       8.42      8.42
# Georgia               2009       5.15      5.15       6.01      6.01
# ...

# %%
# We are selecting the rows where Year = 2010, and grouping by state. We are interested in the
# year 2010 for the peace percentage analysis, and we are grouping by state so that we can 
# combine with the other tables by state.

MinWage_2010 = MinWage_df_transformed.loc[MinWage_df_transformed['year'] == 2010]
MinWage_2010 = MinWage_2010.groupby('state').mean()
MinWage_2010
# Out:
#                       year  high_wage  low_wage  high_2018  low_2018
# state
# Alabama               2010       0.00      0.00       0.00      0.00
# Alaska                2010       7.75      7.75       8.90      8.90
# Arizona               2010       7.25      7.25       8.33      8.33
# Arkansas              2010       6.25      6.25       7.18      7.18
# California            2010       8.00      8.00       9.19      9.19
# Colorado              2010       7.24      7.24       8.31      8.31
# Connecticut           2010       8.25      8.25       9.47      9.47
# Delaware              2010       7.25      7.25       8.33      8.33
# District of Columbia  2010       8.25      8.25       9.47      9.47
# Federal (FLSA)        2010       7.25      7.25       8.33      8.33
# Florida               2010       7.25      7.25       8.33      8.33
# Georgia               2010       5.15      5.15       5.91      5.91
# ...

# %% [markdown]
# ### The metrics dataset contains the following columns 1. state, 2. percentage of educational attainment, which displays the number of individuals that have earned a bachelor's degree or higher during 2009, 3. percent peace index which is measured based on homicide, violent crime, policing, incarceration and availability of small arms rates in 2010. Data was converted to percentages; the higher the % the "more peaceful" the state, 4. Above poverty rate, or the number of households living above  poverty level, converted into %, 5. Percent non-religious is the % of individuals that do not identify as "highly religious."

# %%
# For our first DataFrame, we are interested in extracting the percentage of educational attainment in 2009 and state 
# columns. Therefore, we create a new variable that holds the names for the columns of interest. Then a new 
# DataFrame is created, which contains only the columns stored in the previous variable. 
# A copy of the original dataframe is made to create the second DataFrame, so that the original is kept intact. 
# The columns of this new DataFrame are renamed to the column names given in the SQL tables.

MetricsEdu_cols = ["State", "Percent Educational Attainment"]
MetricsEdu_df = Metrics_df[MetricsEdu_cols].copy()

# Rename the column headers
MetricsEdu_df = MetricsEdu_df.rename(columns={"State":"state",
                                              "Percent Educational Attainment": "education_percent"
                                                              })
MetricsEdu_df = MetricsEdu_df.set_index('state')
MetricsEdu_df.head()
# Out:
#                education_percent
# state
# Massachusetts               38.2
# Maryland                    37.3
# Colorado                    35.9
# Connecticut                 35.6
# New Jersey                  34.5

# %%
# We create a separate table becuase the year for this metric is different. 

# For our second DataFrame, we are interested in extracting the percent peace index in 2010 and state  
# columns. Therefore, we create a new variable that holds the names for the columns of interest. Then a new 
# DataFrame is created, which contains only the columns stored in the previous variable. 
# A copy of the original dataframe is made to create the second DataFrame, so that the original is kept intact. 
# The columns of this new DataFrame are renamed to the column names given in the SQL tables.

MetricsPeace_cols = ["State", "Percent Peace Index"]
MetricsPeace_df = Metrics_df[MetricsPeace_cols].copy()

# Rename the column headers
MetricsPeace_df = MetricsPeace_df.rename(columns={"State":"state",
                                                  "Percent Peace Index": "peace_percent"
                                                                       })
MetricsPeace_df = MetricsPeace_df.set_index('state')
MetricsPeace_df.head()
# Out:
#                peace_percent
# state
# Massachusetts          59.92
# Maryland               37.10
# Colorado               49.48
# Connecticut            56.12
# New Jersey             47.38

# %% [markdown]
# # UPLOAD

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5433/ETL_db')

# %%
# Confirm tables
engine.table_names()
# Out:
# [u'wage_2009', u'wage_2010', u'education', u'peace']

# %%
# Load DataFrame 'MinWage_df_transformed' into table 'wage_2009' in database 'ETLproject_db'
MinWage_2009.to_sql(name='wage_2009', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-35-d9a9b6177172> in <module>()
#       1 # Load DataFrame 'MinWage_df_transformed' into table 'wage_2009' in database 'ETLproject_db'
# ----> 2 MinWage_2009.to_sql(name='wage_2009', con=engine, if_exists='append', index=True)
#
# /Users/manuelahoyosgiraldo/opt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ...

# %%
# Load DataFrame 'MinWage_df_transformed' into table 'wage_2010' in database 'ETLproject_db'
MinWage_2010.to_sql(name='wage_2010', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-36-1208983a2093> in <module>()
#       1 # Load DataFrame 'MinWage_df_transformed' into table 'wage_2010' in database 'ETLproject_db'
# ----> 2 MinWage_2010.to_sql(name='wage_2010', con=engine, if_exists='append', index=True)
#
# /Users/manuelahoyosgiraldo/opt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ...

# %%
# Load DataFrame 'MetricsEdu_df_transformed' into table 'education' in database 'ETLproject_db'
MetricsEdu_df.to_sql(name='education', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-37-09213b510bf9> in <module>()
#       1 # Load DataFrame 'MetricsEdu_df_transformed' into table 'education' in database 'ETLproject_db'
# ----> 2 MetricsEdu_df.to_sql(name='education', con=engine, if_exists='append', index=True)
#
# /Users/manuelahoyosgiraldo/opt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ...

# %%
# Load DataFrame 'MetricsPeace_df_transformed' into table 'peace' in database 'ETLproject_db'
MetricsPeace_df.to_sql(name='peace', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-38-8d1137d049d6> in <module>()
#       1 # Load DataFrame 'MetricsPeace_df_transformed' into table 'peace' in database 'ETLproject_db'
# ----> 2 MetricsPeace_df.to_sql(name='peace', con=engine, if_exists='append', index=True)
#
# /Users/manuelahoyosgiraldo/opt/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ...

# %%
#### SELECT wage_2009.year, wage_2009.state, wage_2009.high_wage, wage_2009.low_wage, 
#### wage_2009.high_2018, wage_2009.low_2018, education.state, education.education_percent 
#### FROM wage_2009
#### JOIN education
#### ON wage_2009.state = education.state;

#### SELECT wage_2010.year, wage_2010.state, wage_2010.high_wage, wage_2010.low_wage, 
#### wage_2010.high_2018, wage_2010.low_2018, peace.peace_percent 
#### FROM wage_2010
#### JOIN peace
#### ON wage_2010.state = peace.state;

# %% [markdown]
# ## Hypothesis 1: Minimum wage and educational attainment were directly proportional during 2009: the higher the minimum wage, the higher the % of educational attainment; the lower the minimum wage, the lower the % of educational attainment.
# ## Hypothesis 2: Minimum wage and % peace index were directly proportional in 2010: the higher the minimum wage, the higher the % peace index; the lower the minimum wage, the lower the % peace index.

# %% [markdown]
# ### In the next process we will merge the DataFrames. Then we will show the ten states with the highest minimum wage and the ten states with the lowest minimum wage during 2009. We want to extract only 20 states from the DataFrame to be able to plot the data and determine how the highest and lowest minimum wage values were related to educational attainment percent during that same year.
#
# ### The same will be done with the highest and lowest minimum wage values in the year 2010 and peace index percent to be able to plot the data and determine how the highest and lowest minimum wage values were related to peace index percent during that same year.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.ticker as mtick  # pip install mtick

# %%
# Merge 'MetricsEdu_df' and 'MinWage_2009'DataFrames into a single dataset
education_per_df = pd.merge(MinWage_2009, MetricsEdu_df, how="outer", on="state")
education_per = education_per_df.drop(columns=['high_2018', 'low_2018',"year"])
education_per.head()

# Sort MetricsEdu data data by high_wage and low_wage to get 10 states with highest and lowest minimum wage 
high_sort = education_per.sort_values(by='high_wage', ascending=False, na_position='first')
high_sort.head()
low_sort = education_per.sort_values(by=['low_wage'])
low_sort.head()
# Out:
#                 high_wage  low_wage  education_percent
# state
# Alabama               0.0       0.0               22.0
# Tennessee             0.0       0.0               23.0
# South Carolina        0.0       0.0               24.3
# Mississippi           0.0       0.0               19.6
# Louisiana             0.0       0.0               21.4

# %%
# Extract the ten states with the highest minimum wage values in 2009 
metrics_edu = education_per.loc[["Washington", "Oregon", "Vermont", "Connecticut", "Massachusetts", "California",
                                 "Illinois", "Michigan", "Rhode Island", "Ohio"]]
# Reset Index
metrics_edu = metrics_edu.reset_index()
# Display Data
metrics_edu

# Extract the ten states with the lowest minimum wage values in 2009 
lowest_wage_st = education_per.loc[["Oklahoma", "Kansas", "Montana", "Georgia", "Wyoming", "Minnesota", 
                             "Arkansas", "Wisconsin", "Nevada", "North Carolina"]]
# Reset Index
lowest_wage = lowest_wage_st.reset_index()
# Display Data
lowest_wage

# Print both datas to see result
print ("high_wage:")
display(metrics_edu.head())
print ("___________________________________________")
print ("")
print ("low_wage:")
display(lowest_wage.head())
# Out:
# high_wage:
#            state  high_wage  low_wage  education_percent
# 0     Washington       8.55      8.55               31.0
# 1         Oregon       8.40      8.40               29.2
# 2        Vermont       8.06      8.06               33.1
# 3    Connecticut       8.00      8.00               35.6
# 4  Massachusetts       8.00      8.00               38.2
# ___________________________________________
#
# low_wage:
#       state  high_wage  low_wage  education_percent
# 0  Oklahoma       6.55      2.00               22.7
# 1    Kansas       2.65      2.65               29.5
# 2   Montana       6.90      4.00               27.4
# 3   Georgia       5.15      5.15               27.5
# 4   Wyoming       5.15      5.15               23.8

# %%
# Define hight_wage column
y1 = metrics_edu["high_wage"].values

# Create bar plot
fig, ax = plt.subplots(figsize = (8.5, 5))
metrics_eduplt = plt.bar(metrics_edu["state"], metrics_edu["education_percent"], 
                         color = "#39ac6d", edgecolor='black', lw=0.5)

# Add % sign to the ticks
fmt = '{x:,.0f}%'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# Add title
plt.title("Maximum Wage of 2009 (highest) -vs- Percent of Educational Attainment")
plt.ylabel("Percent of Educational Attainment", size=10)

# Set up Education Percent by wage
def autolabel(rects):
    for i,rect in enumerate(rects):
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., 1.0*height, '$%s'% (y1[i]), ha="center", va='top',
                 color="white", weight="bold", fontsize=12)

# Set up grid
plt.grid('on', which='major', axis='y', linestyle='-', lw=1)

# Giving rotation to states
plt.xticks(rotation=15)

# Save our graph and show the grap
plt.tight_layout()
file1=plt.savefig("../Images/MaxWage_2009_vs_MetricsEdu_df.png")
autolabel(metrics_eduplt)
plt.show()

# %%
# Define high_wage column 
y2 = lowest_wage["low_wage"].values

# Create bar plot
fig, ax = plt.subplots(figsize = (8.5, 5))
lowest_wageplt = plt.bar(lowest_wage["state"], lowest_wage["education_percent"], 
                         color = "#b30000", edgecolor='black', lw=0.5)

# Adding to the ticks % sign
fmt = '{x:,.0f}%'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# Creating title 
plt.title("Minimum Wage of 2009 (lowest) -vs- Percent of Educational Attainment")
plt.ylabel("Percent of Educational Attainment", size=10)

# Set up Education Percent by wage
def autolabel(rects):
    for i,rect in enumerate(rects):
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., 1.0*height, '$%s'% (y2[i]), ha="center", va='top',
                 color="white", weight="bold", fontsize=12.5)
                  
# Set up grid
plt.grid('on', which='major', axis='y', linestyle='-', lw=1)

# Giving rotation to states
plt.xticks(rotation=15)

# Save our graph and show the grap
plt.tight_layout()
file2=plt.savefig("../Images/MinWage_2009_vs_MetricsEdu_df.png")
autolabel(lowest_wageplt)
plt.show()

# %%
# Merge the two barplots
# Define hight_wage and low_wage columns 
y1 = metrics_edu["high_wage"].values
y2 = lowest_wage["low_wage"].values

#Create axis titles
fig, ax = plt.subplots(figsize = (14.5, 6))
metrics_eduplt = ax.bar(metrics_edu["state"], metrics_edu["education_percent"], 
                        color = "#39ac6d", label = "Highest Minimum Wage", edgecolor='black', lw=0.5)
lowest_wageplt = ax.bar(lowest_wage["state"], lowest_wage["education_percent"], 
                        color = "#b30000", label = "Lowest Minimum Wage", edgecolor='black', lw=0.5)

# Set up Education Percent by wage
def autolabel(rects):
    for i, rect in enumerate(rects):
        
        height = rect.get_height()
        height_bar = y_y[i]
        height_barr = y_1[i]

        if height_bar >= 7.0:
            plt.text(rect.get_x() + rect.get_width()/2., 1.0*height,'$%s'% (height_bar), 
                ha="center", va='top', color="white", weight="bold", fontsize=10.7)
        else:   
            plt.text(rect.get_x() + rect.get_width()/2., 1.0*height,'$%s'% (height_barr),
                ha="center", va='bottom', color="black", weight="bold", fontsize=10.7)
    
    #plt.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height, '{}'.format(height), '$%s'% (y[i]), 
            #ha=ha[xpos], va='bottom',color="white", weight="bold", fontsize=10.7)
            single_bar_group={metrics_eduplt[i].get_height():metrics_eduplt[i].get_x() + metrics_eduplt[i].get_width()/3.0,
                              lowest_wageplt[i].get_height():lowest_wageplt[i].get_x() + lowest_wageplt[i].get_width()/3.0}

# Adding to the ticks % sign
fmt = '{x:,.0f}%'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
            
# Set up grid
plt.grid('on', which='major', axis='y', linestyle='-', lw=1)

# Creating title 
plt.title("Minimum Wage in 2009 -vs- Metrics Education Percent")         
plt.ylabel("Percent of Educational Attainment", size=10)

# Giving rotation to states
plt.xticks(rotation=30)

# Save our graph and show the grap
autolabel(metrics_eduplt)
autolabel(lowest_wageplt)
file3=plt.savefig("../Images/comb_MaxAndMin_edu.png")
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-463e792e0fa6> in <module>()
#      47
#      48 # Save our graph and show the grap
# ---> 49 autolabel(metrics_eduplt)
#      50 autolabel(lowest_wageplt)
#      51 file3=plt.savefig("../Images/comb_MaxAndMin_edu.png")
#
# <ipython-input-47-463e792e0fa6> in autolabel(rects)
#      16
#      17         height = rect.get_height()
# ---> 18         height_bar = y_y[i]
#      19         height_barr = y_1[i]
#      20
#
# NameError: global name 'y_y' is not defined

# %% [markdown]
# ## Results: educational attainment and minimum wage were unrelated during the year 2009. The state with the highest minimum wage was Washington (8.55/hour, equivalent to 9.98/hour in 2018). However, this state was not the state with the highest % of education attainment during that same year. Moreover, the state with the lowest minimum wage value was Oklahoma (2.00/hour, equivalent to 2.33/hours in 2018). Similarly, this is not the state with the lowest % of educational attainment.

# %%
# Merge 'MetricsPeace_df' and 'MinWage_2010' DataFrames into a single one 
met_peace_df = pd.merge(MinWage_2010, MetricsPeace_df, how="outer", on="state")
met_peace = met_peace_df.drop(columns=['high_2018', 'low_2018', "year"])
met_peace.head()

# Sort MetricsPeace data by high_wage and low_wage to get 10 states with highest wage and lowest one
high_sort_peace = met_peace.sort_values(by='high_wage', ascending=False, na_position='first')
high_sort_peace.head()
low_sort_peace = met_peace.sort_values(by=['low_wage'])
low_sort_peace.head()
# Out:
#                 high_wage  low_wage  peace_percent
# state
# Alabama               0.0       0.0          36.60
# Tennessee             0.0       0.0          31.74
# South Carolina        0.0       0.0          36.44
# Mississippi           0.0       0.0          36.60
# Louisiana             0.0       0.0          19.02

# %%
# Extract the ten states with the highest minimum wage values in 2009 
metric_peace_new = met_peace.loc[["Washington", "Oregon", "Vermont", "Connecticut", "Massachusetts", "California",
                                  "Illinois", "Michigan", "Rhode Island", "Ohio"]]
# Reset Index
hight_wage_df = metric_peace_new.reset_index()
hight_wage_df

# Extract the ten states with the lowest minimum wage values in 2009 
metric_peace_neww = met_peace.loc[["Oklahoma", "Kansas", "Montana", "Georgia", "Wyoming", "Minnesota", 
                                    "Arkansas", "Wisconsin", "Nevada", "North Carolina"]]
# Reset Index
low_wage_df = metric_peace_neww.reset_index()
low_wage_df

# Print both datas to see result
print ("Sorted by high wage:")
display(hight_wage_df.head())
print ("___________________________________________")
print ("")
print ("Sorted by low wage:")
display(low_wage_df.head())
# Out:
# Sorted by high wage:
#            state  high_wage  low_wage  peace_percent
# 0     Washington       8.55      8.55          64.36
# 1         Oregon       8.40      8.40          58.56
# 2        Vermont       8.06      8.06          69.06
# 3    Connecticut       8.25      8.25          56.12
# 4  Massachusetts       8.00      8.00          59.92
# ___________________________________________
#
# Sorted by low wage:
#       state  high_wage  low_wage  peace_percent
# 0  Oklahoma       7.25      2.00          37.78
# 1    Kansas       7.25      7.25          48.54
# 2   Montana       7.25      4.00          54.54
# 3   Georgia       5.15      5.15          39.20
# 4   Wyoming       5.15      5.15          54.72

# %%
# Define hight_wage column
y_y = hight_wage_df["high_wage"].values

# Create barplot
fig, ax = plt.subplots(figsize = (8, 5))
highest_wage = plt.bar(hight_wage_df["state"], hight_wage_df["peace_percent"], 
                       color = "#39ac6d", edgecolor='black', lw=0.5)

# Adding to the ticks % sign
fmt = '{x:,.0f}%'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

#Creating title and ylabel
plt.title("Minimum Wage (highest) of 2010 -vs- Peace Percent")
plt.ylabel("Percent of Peace Index", size=10)

# Set up Peace Percent by wage
def autolabel(rects):
    for i,rect in enumerate(rects):
        
        height = rect.get_height()
        
        plt.text(rect.get_x() + rect.get_width()/2.,1.*height, '$%s'% (y_y[i]), ha="center", va='top',
                 color="white", weight="bold", fontsize=12.5)
# Set up grid
plt.grid('on', which='major', axis='y', linestyle='-', lw=1)

# Giving rotation to states
plt.xticks(rotation=15)

# Save our graph and show the grap
plt.tight_layout()
file1=plt.savefig("../Images/Highest_Wage_2010_vs_Peace_Index.png")
autolabel(highest_wage)
plt.show()

# %%
# Define low_wage column
y_1 = low_wage_df["low_wage"].values

# Create barplot
fig, ax = plt.subplots(figsize = (8, 5))
lowest_wage_df = plt.bar(low_wage_df["state"], low_wage_df["peace_percent"], 
                         color = "#b30000", edgecolor='black', lw=0.5)

# Adding % sign to the ticks 
fmt = '{x:,.0f}%'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# Create title and ylable
plt.title("Minimum Wage (minimum) of 2010 -vs- Peace Percent")
plt.ylabel("Percent of Peace Index", size=10)

# Set up Peace Percent by wage
def autolabel(rects):
    for i,rect in enumerate(rects):
        
        height = rect.get_height()
        
        plt.text(rect.get_x() + rect.get_width()/2.,1.*height, '$%s'% (y_1[i]), ha="center", va='top',
                 color="white", weight="bold", fontsize=12)
# Set up grid
plt.grid('on', which='major', axis='y', linestyle='-', lw=1)

# Giving rotation to states
plt.xticks(rotation=15)

# Save our graph and show the grap
plt.ylabel("Percent of Peace Index", size=10)
plt.tight_layout()
file2=plt.savefig("../Images/Lowest_Wage_2010_vs_Peace_Index.png")
autolabel(lowest_wage_df)
plt.show()

# %%
# Merging two barplots
# Define high_wage and low_wage columns
y_y = hight_wage_df["high_wage"].values
y_1 = low_wage_df["low_wage"].values

# Create barplot
fig, ax = plt.subplots(figsize = (14.5, 6))

highest_wageplt = ax.bar(hight_wage_df["state"], hight_wage_df["peace_percent"], 
                         color = "#39ac6d", label = "Highest Minimum Wage", edgecolor='black', lw=0.5)
lowest_wage_dfplt = ax.bar(low_wage_df["state"], low_wage_df["peace_percent"], 
                           color = "#b30000", label = "Lowest Minimum Wage", edgecolor='black', lw=0.5)

# Set up price by Roofor each bar
def autolabel(rects):
    for i, rect in enumerate(rects):
        
        height = rect.get_height()
        height_bar = y_y[i]
        height_barr = y_1[i]

        if height_bar >= 7.0:
            plt.text(rect.get_x() + rect.get_width()/2., 1.0*height,'$%s'% (height_bar), 
                ha="center", va='top', color="white", weight="bold", fontsize=10.7)
        else:   
            plt.text(rect.get_x() + rect.get_width()/2., 1.0*height,'$%s'% (height_barr),
                ha="center", va='bottom', color="black", weight="bold", fontsize=10.7)
    
    #plt.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height, '{}'.format(height), '$%s'% (y[i]), 
                #ha=ha[xpos], va='bottom',color="white", weight="bold", fontsize=10.7)
            single_bar_group={metrics_eduplt[i].get_height():metrics_eduplt[i].get_x() + metrics_eduplt[i].get_width()/3.0,
                              lowest_wageplt[i].get_height():lowest_wageplt[i].get_x() + lowest_wageplt[i].get_width()/3.0}
# Creating title and ylable
plt.title("Minimum Wage of 2010 -vs- Peace Percent")
plt.ylabel("Percent of Peace Index", size=10)

# Adding to the ticks % sign
fmt = '{x:,.0f}%'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# Giving rotation to states
plt.xticks(rotation=30)
            
# Save our graph and show the grap
autolabel(highest_wageplt)
autolabel(lowest_wage_dfplt)
file3=plt.savefig("../Images/comb_MaxAndMin_peace.png")
ax.legend()
plt.show()

# %% [markdown]
# ## Results: peace percent and minimum wage were unrelated during the year 2010. The state with the highest minimum wage was Washington (8.55/hour, eqivalent to 9.82/hour in 2018). However, this state was not the state with the highest peace % during that same year. Moreover, the state with the lowest minimum wage value was Oklahoma (2.00/hour, equivalent to 2.30/hours in 2018). Similarly, this is not the state with the lowest peace %.
